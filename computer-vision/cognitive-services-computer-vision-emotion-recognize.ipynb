# %% [markdown]
# # Emotion Recognize
#
# This demo use **Microsoft Azure Cognitive Services**.

# %%
import time 
import requests
import cv2
import operator
import numpy as np
from __future__ import print_function
import matplotlib.pyplot as plt
# %matplotlib inline 

_url = 'https://westus.api.cognitive.microsoft.com/emotion/v1.0/recognize'
_key = '__KEY__'
_maxNumRetries = 10

# %%
def processRequest( json, data, headers, params ):
    retries = 0
    result = None

    while True:

        response = requests.request( 'post', _url, json = json, data = data, headers = headers, params = params )

        if response.status_code == 429: 

            print( "Message: %s" % ( response.json()['error']['message'] ) )

            if retries <= _maxNumRetries: 
                time.sleep(1) 
                retries += 1
                continue
            else: 
                print( 'Error: failed after retrying!' )
                break

        elif response.status_code == 200 or response.status_code == 201:

            if 'content-length' in response.headers and int(response.headers['content-length']) == 0: 
                result = None 
            elif 'content-type' in response.headers and isinstance(response.headers['content-type'], str): 
                if 'application/json' in response.headers['content-type'].lower(): 
                    result = response.json() if response.content else None 
                elif 'image' in response.headers['content-type'].lower(): 
                    result = response.content
        else:
            print( "Error code: %d" % ( response.status_code ) )
            print( "Message: %s" % ( response.json()['error']['message'] ) )

        break
        
    return result

# %%
def renderResultOnImage( result, img ):
    
    for currFace in result:
        faceRectangle = currFace['faceRectangle']
        cv2.rectangle( img,(faceRectangle['left'],faceRectangle['top']),
                           (faceRectangle['left']+faceRectangle['width'], faceRectangle['top'] + faceRectangle['height']),
                       color = (255,0,0), thickness = 5 )

    for currFace in result:
        faceRectangle = currFace['faceRectangle']
        currEmotion = max(currFace['scores'].items(), key=operator.itemgetter(1))[0]


        textToWrite = "%s" % ( currEmotion )
        cv2.putText( img, textToWrite, (faceRectangle['left'],faceRectangle['top']-10), cv2.FONT_HERSHEY_SIMPLEX, 1.5, (255,0,0), 2 )

# %%
from IPython.display import Image as ipImage, display

urlImage = 'http://meriatblob.blob.core.windows.net/demos/cognitive/faces.jpeg'

img = ipImage(url=urlImage, width=600)
display(img)
# Out:
# <img src="http://meriatblob.blob.core.windows.net/demos/cognitive/faces.jpeg" width="600"/>

# %%
headers = dict()
headers['Ocp-Apim-Subscription-Key'] = _key
headers['Content-Type'] = 'application/json' 

json = { 'url': urlImage } 
data = None
params = None

result = processRequest( json, data, headers, params )

# %%
if result is not None:
    # Carrega a imagem original para desenhar o conteúdo
    arr = np.asarray( bytearray( requests.get( urlImage ).content ), dtype=np.uint8 )
    img = cv2.cvtColor( cv2.imdecode( arr, -1 ), cv2.COLOR_BGR2RGB )

    renderResultOnImage( result, img )

    ig, ax = plt.subplots(figsize=(15, 20))
    ax.imshow( img )

# %%
import json

print(json.dumps(result, indent=2, sort_keys=True))
# Out:
# [
#   {
#     "faceRectangle": {
#       "height": 182,
#       "left": 1400,
#       "top": 1192,
#       "width": 182
#     },
#     "scores": {
#       "anger": 0.00238924846,
#       "contempt": 7.497336e-05,
#       "disgust": 0.045775678,
#       "fear": 2.73777459e-05,
#       "happiness": 0.9441689,
#       "neutral": 0.00174475054,
#       "sadness": 0.00109974784,
#       "surprise": 0.004719289
#     }
#   },
#   {
#     "faceRectangle": {
#       "height": 182,
#       "left": 1407,
#       "top": 1452,
#       "width": 182
#     },
#     "scores": {
#       "anger": 2.87767726e-10,
#       "contempt": 7.555216e-12,
#       "disgust": 1.46385517e-08,
#       "fear": 6.407166e-11,
#       "happiness": 0.99999696,
#       "neutral": 2.00409822e-09,
#       "sadness": 2.31166891e-11,
#       "surprise": 3.02986541e-06
#     }
#   },
#   {
#     "faceRectangle": {
#       "height": 180,
#       "left": 603,
#       "top": 1387,
#       "width": 180
#     },
#     "scores": {
#       "anger": 2.975419e-06,
#       "contempt": 2.57064023e-08,
#       "disgust": 1.93089772e-06,
#       "fear": 3.42393447e-10,
#       "happiness": 0.9999948,
#       "neutral": 2.27384234e-07,
#       "sadness": 1.97093311e-08,
#       "surprise": 9.636905e-09
#     }
#   },
#   {
#     "faceRectangle": {
#       "height": 177,
#       "left": 685,
#       "top": 1163,
#       "width": 177
#     },
#     "scores": {
#       "anger": 2.99756227e-11,
#       "contempt": 1.66977723e-10,
#       "disgust": 1.35066985e-10,
#       "fear": 7.810955e-14,
#       "happiness": 0.99999994,
#       "neutral": 3.29889644e-08,
#       "sadness": 3.25580951e-11,
#       "surprise": 6.030833e-10
#     }
#   },
#   {
#     "faceRectangle": {
#       "height": 177,
#       "left": 1196,
#       "top": 1000,
#       "width": 177
#     },
#     "scores": {
#       "anger": 4.867478e-09,
#       "contempt": 1.25357554e-11,
#       "disgust": 3.04197223e-09,
#       "fear": 8.513078e-11,
#       "happiness": 1.0,
#       "neutral": 6.457955e-11,
#       "sadness": 6.049309e-11,
#       "surprise": 1.89015239e-08
#     }
#   },
#   {
#     "faceRectangle": {
#       "height": 177,
#       "left": 453,
#       "top": 1158,
#       "width": 177
#     },
#     "scores": {
#       "anger": 2.46060836e-07,
#       "contempt": 4.23151647e-08,
#       "disgust": 4.80603876e-06,
#       "fear": 2.26632455e-08,
#       "happiness": 0.999929965,
#       "neutral": 2.32271141e-05,
#       "sadness": 9.445113e-07,
#       "surprise": 4.07601874e-05
#     }
#   },
#   {
#     "faceRectangle": {
#       "height": 169,
#       "left": 2227,
#       "top": 1064,
#       "width": 169
#     },
#     "scores": {
#       "anger": 2.22300867e-09,
#       "contempt": 6.660461e-11,
#       "disgust": 1.03221204e-07,
#       "fear": 1.05135193e-12,
#       "happiness": 0.9999999,
#       "neutral": 3.740462e-09,
#       "sadness": 1.954067e-10,
#       "surprise": 6.61569866e-09
#     }
#   },
#   {
#     "faceRectangle": {
#       "height": 165,
#       "left": 1718,
#       "top": 1215,
#       "width": 165
#     },
#     "scores": {
#       "anger": 3.23243272e-11,
#       "contempt": 2.99090017e-13,
#       "disgust": 1.33357519e-10,
#       "fear": 6.247066e-14,
#       "happiness": 1.0,
#       "neutral": 1.82720089e-11,
#       "sadness": 1.07543878e-12,
#       "surprise": 6.677201e-11
#     }
#   },
#   {
#     "faceRectangle": {
#       "height": 164,
#       "left": 821,
#       "top": 834,
#       "width": 164
#     },
#     "scores": {
#       "anger": 1.917113e-10,
#       "contempt": 6.37381536e-10,
#       "disgust": 1.06457128e-08,
#       "fear": 7.062026e-13,
#       "happiness": 1.0,
#       "neutral": 1.19149952e-08,
#       "sadness": 8.09196737e-11,
#       "surprise": 9.395557e-10
#     }
#   },
#   {
#     "faceRectangle": {
#       "height": 163,
#       "left": 1994,
#       "top": 812,
#       "width": 163
#     },
#     "scores": {
#       "anger": 3.18983148e-05,
#       "contempt": 0.000165950361,
#       "disgust": 0.000599719235,
#       "fear": 1.28502208e-07,
#       "happiness": 0.9906459,
#       "neutral": 0.008533982,
#       "sadness": 4.12130657e-06,
#       "surprise": 1.83407683e-05
#     }
#   },
#   {
#     "faceRectangle": {
#       "height": 158,
#       "left": 1860,
#       "top": 1451,
#       "width": 158
#     },
#     "scores": {
#       "anger": 2.02949723e-05,
#       "contempt": 4.93339e-10,
#       "disgust": 1.86099976e-06,
#       "fear": 3.50422746e-10,
#       "happiness": 0.99997735,
#       "neutral": 8.781921e-08,
#       "sadness": 4.032055e-07,
#       "surprise": 2.28369257e-09
#     }
#   },
#   {
#     "faceRectangle": {
#       "height": 157,
#       "left": 81,
#       "top": 1368,
#       "width": 157
#     },
#     "scores": {
#       "anger": 0.000130514134,
#       "contempt": 7.952322e-06,
#       "disgust": 0.0005116569,
#       "fear": 2.9236553e-06,
#       "happiness": 0.998465657,
#       "neutral": 0.000406017381,
#       "sadness": 0.000456051173,
#       "surprise": 1.92559764e-05
#     }
#   },
#   {
#     "faceRectangle": {
#       "height": 156,
#       "left": 475,
#       "top": 1002,
#       "width": 156
#     },
#     "scores": {
#       "anger": 1.1607639e-05,
#       "contempt": 3.480006e-05,
#       "disgust": 4.50504967e-06,
#       "fear": 1.65840606e-06,
#       "happiness": 0.9452685,
#       "neutral": 0.0538166724,
#       "sadness": 0.0007430568,
#       "surprise": 0.0001191614
#     }
#   },
#   {
#     "faceRectangle": {
#       "height": 154,
#       "left": 1500,
#       "top": 806,
#       "width": 154
#     },
#     "scores": {
#       "anger": 1.3521043e-08,
#       "contempt": 8.414921e-12,
#       "disgust": 3.65406727e-08,
#       "fear": 7.561722e-13,
#       "happiness": 0.99999994,
#       "neutral": 6.873749e-11,
#       "sadness": 6.451627e-11,
#       "surprise": 1.56220381e-09
#     }
#   },
#   {
#     "faceRectangle": {
#       "height": 153,
#       "left": 237,
#       "top": 872,
#       "width": 153
#     },
#     "scores": {
#       "anger": 0.000248110562,
#       "contempt": 0.008822054,
#       "disgust": 0.000281930639,
#       "fear": 0.000123510064,
#       "happiness": 0.0277539864,
#       "neutral": 0.8964554,
#       "sadness": 0.06582792,
#       "surprise": 0.000487077632
#     }
#   },
#   {
#     "faceRectangle": {
#       "height": 152,
#       "left": 379,
#       "top": 517,
#       "width": 152
#     },
#     "scores": {
#       "anger": 4.50758635e-05,
#       "contempt": 1.69098313e-09,
#       "disgust": 1.17300624e-06,
#       "fear": 2.32359028e-07,
#       "happiness": 0.999950767,
#       "neutral": 2.47175e-08,
#       "sadness": 7.176069e-10,
#       "surprise": 2.737557e-06
#     }
#   },
#   {
#     "faceRectangle": {
#       "height": 151,
#       "left": 1688,
#       "top": 1019,
#       "width": 151
#     },
#     "scores": {
#       "anger": 5.893627e-09,
#       "contempt": 7.540152e-12,
#       "disgust": 7.19649362e-09,
#       "fear": 2.65966448e-13,
#       "happiness": 1.0,
#       "neutral": 1.948061e-10,
#       "sadness": 1.61642921e-10,
#       "surprise": 4.838464e-11
#     }
#   },
#   {
#     "faceRectangle": {
#       "height": 150,
#       "left": 1000,
#       "top": 557,
#       "width": 150
#     },
#     "scores": {
#       "anger": 1.161275e-07,
#       "contempt": 2.23599983e-08,
#       "disgust": 2.03576337e-06,
#       "fear": 8.870258e-12,
#       "happiness": 0.999997437,
#       "neutral": 4.08290362e-07,
#       "sadness": 2.05185882e-10,
#       "surprise": 8.736616e-09
#     }
#   },
#   {
#     "faceRectangle": {
#       "height": 147,
#       "left": 2296,
#       "top": 510,
#       "width": 147
#     },
#     "scores": {
#       "anger": 2.46576087e-06,
#       "contempt": 5.60510841e-07,
#       "disgust": 0.000164569472,
#       "fear": 7.09719972e-09,
#       "happiness": 0.9996162,
#       "neutral": 0.000176367452,
#       "sadness": 2.55006626e-06,
#       "surprise": 3.72477734e-05
#     }
#   },
#   {
#     "faceRectangle": {
#       "height": 144,
#       "left": 1122,
#       "top": 304,
#       "width": 144
#     },
#     "scores": {
#       "anger": 0.0008615766,
#       "contempt": 0.00946854,
#       "disgust": 0.003696635,
#       "fear": 5.51124549e-06,
#       "happiness": 0.660124242,
#       "neutral": 0.325387359,
#       "sadness": 0.000305619615,
#       "surprise": 0.000150494874
#     }
#   },
#   {
#     "faceRectangle": {
#       "height": 142,
#       "left": 1786,
#       "top": 696,
#       "width": 142
#     },
#     "scores": {
#       "anger": 6.26103756e-08,
#       "contempt": 1.59120714e-06,
#       "disgust": 3.25296082e-06,
#       "fear": 2.60527244e-09,
#       "happiness": 0.999957442,
#       "neutral": 3.442307e-05,
#       "sadness": 1.43372426e-06,
#       "surprise": 1.81272219e-06
#     }
#   },
#   {
#     "faceRectangle": {
#       "height": 142,
#       "left": 22,
#       "top": 1190,
#       "width": 142
#     },
#     "scores": {
#       "anger": 0.0003040716,
#       "contempt": 5.877828e-07,
#       "disgust": 8.25724637e-05,
#       "fear": 5.39781468e-06,
#       "happiness": 0.999128938,
#       "neutral": 0.000156154085,
#       "sadness": 0.000262514863,
#       "surprise": 5.97763174e-05
#     }
#   },
#   {
#     "faceRectangle": {
#       "height": 140,
#       "left": 1895,
#       "top": 380,
#       "width": 140
#     },
#     "scores": {
#       "anger": 2.48898459e-07,
#       "contempt": 8.253983e-09,
#       "disgust": 1.53150233e-06,
#       "fear": 2.6673444e-10,
#       "happiness": 0.9999979,
#       "neutral": 1.93895573e-07,
#       "sadness": 4.161937e-09,
#       "surprise": 8.465146e-08
#     }
#   },
#   {
#     "faceRectangle": {
#       "height": 138,
#       "left": 1423,
#       "top": 593,
#       "width": 138
#     },
#     "scores": {
#       "anger": 5.455193e-09,
#       "contempt": 8.502875e-09,
#       "disgust": 5.63981821e-08,
#       "fear": 1.61755852e-12,
#       "happiness": 0.9999975,
#       "neutral": 2.44221269e-06,
#       "sadness": 6.630456e-11,
#       "surprise": 1.86018967e-09
#     }
#   },
#   {
#     "faceRectangle": {
#       "height": 138,
#       "left": 158,
#       "top": 406,
#       "width": 138
#     },
#     "scores": {
#       "anger": 8.966705e-10,
#       "contempt": 6.1626737e-10,
#       "disgust": 2.99029024e-09,
#       "fear": 4.47369979e-13,
#       "happiness": 1.0,
#       "neutral": 1.15510468e-09,
#       "sadness": 3.613062e-11,
#       "surprise": 1.49485563e-10
#     }
#   },
#   {
#     "faceRectangle": {
#       "height": 137,
#       "left": 2050,
#       "top": 439,
#       "width": 137
#     },
#     "scores": {
#       "anger": 3.458843e-07,
#       "contempt": 2.319121e-07,
#       "disgust": 2.40089576e-05,
#       "fear": 1.17603385e-10,
#       "happiness": 0.9999747,
#       "neutral": 4.53625546e-07,
#       "sadness": 2.790965e-08,
#       "surprise": 2.07730864e-07
#     }
#   },
#   {
#     "faceRectangle": {
#       "height": 135,
#       "left": 705,
#       "top": 462,
#       "width": 135
#     },
#     "scores": {
#       "anger": 1.42576318e-05,
#       "contempt": 1.57499287e-07,
#       "disgust": 7.890891e-06,
#       "fear": 2.452692e-08,
#       "happiness": 0.9999677,
#       "neutral": 8.856447e-06,
#       "sadness": 3.111965e-07,
#       "surprise": 7.92059268e-07
#     }
#   },
#   {
#     "faceRectangle": {
#       "height": 133,
#       "left": 523,
#       "top": 228,
#       "width": 133
#     },
#     "scores": {
#       "anger": 0.0006252399,
#       "contempt": 0.03284305,
#       "disgust": 0.00544255739,
#       "fear": 3.260759e-05,
#       "happiness": 0.5879698,
#       "neutral": 0.3688457,
#       "sadness": 0.00158915645,
#       "surprise": 0.00265194173
#     }
#   },
#   {
#     "faceRectangle": {
#       "height": 131,
#       "left": 1413,
#       "top": 242,
#       "width": 131
#     },
#     "scores": {
#       "anger": 2.70287028e-08,
#       "contempt": 2.69829616e-08,
#       "disgust": 6.228233e-07,
#       "fear": 2.33525838e-10,
#       "happiness": 0.9999984,
#       "neutral": 8.27265637e-07,
#       "sadness": 5.37013456e-08,
#       "surprise": 4.01017175e-08
#     }
#   },
#   {
#     "faceRectangle": {
#       "height": 129,
#       "left": 1633,
#       "top": 440,
#       "width": 129
#     },
#     "scores": {
#       "anger": 1.04372173e-08,
#       "contempt": 7.800489e-10,
#       "disgust": 1.79065953e-08,
#       "fear": 4.93216e-12,
#       "happiness": 0.99999994,
#       "neutral": 5.27590629e-08,
#       "sadness": 6.135135e-10,
#       "surprise": 2.51561882e-09
#     }
#   },
#   {
#     "faceRectangle": {
#       "height": 128,
#       "left": 2224,
#       "top": 212,
#       "width": 128
#     },
#     "scores": {
#       "anger": 4.206594e-05,
#       "contempt": 0.00183002453,
#       "disgust": 0.000220460235,
#       "fear": 4.860958e-06,
#       "happiness": 0.758147359,
#       "neutral": 0.238990217,
#       "sadness": 0.000357536628,
#       "surprise": 0.000407474756
#     }
#   },
#   {
#     "faceRectangle": {
#       "height": 128,
#       "left": 369,
#       "top": 127,
#       "width": 128
#     },
#     "scores": {
#       "anger": 9.739984e-11,
#       "contempt": 1.7872993e-11,
#       "disgust": 1.85890414e-08,
#       "fear": 3.407828e-13,
#       "happiness": 0.99999994,
#       "neutral": 8.47065e-09,
#       "sadness": 5.26673674e-08,
#       "surprise": 5.81184025e-11
#     }
#   },
#   {
#     "faceRectangle": {
#       "height": 121,
#       "left": 2042,
#       "top": 125,
#       "width": 121
#     },
#     "scores": {
#       "anger": 2.02300835e-05,
#       "contempt": 1.93238684e-05,
#       "disgust": 0.0002735665,
#       "fear": 2.55419272e-05,
#       "happiness": 0.9992053,
#       "neutral": 0.0003837731,
#       "sadness": 1.00391744e-05,
#       "surprise": 6.224308e-05
#     }
#   },
#   {
#     "faceRectangle": {
#       "height": 120,
#       "left": 841,
#       "top": 185,
#       "width": 120
#     },
#     "scores": {
#       "anger": 5.51399e-06,
#       "contempt": 3.763402e-05,
#       "disgust": 0.00131890189,
#       "fear": 1.42507144e-08,
#       "happiness": 0.99549824,
#       "neutral": 0.00303859776,
#       "sadness": 0.00010006399,
#       "surprise": 1.024173e-06
#     }
#   },
#   {
#     "faceRectangle": {
#       "height": 120,
#       "left": 204,
#       "top": 267,
#       "width": 120
#     },
#     "scores": {
#       "anger": 0.0001652833,
#       "contempt": 0.000168201848,
#       "disgust": 0.000113346818,
#       "fear": 0.000250517274,
#       "happiness": 0.422267258,
#       "neutral": 0.5542627,
#       "sadness": 0.0174195133,
#       "surprise": 0.005353216
#     }
#   },
#   {
#     "faceRectangle": {
#       "height": 117,
#       "left": 1924,
#       "top": 35,
#       "width": 117
#     },
#     "scores": {
#       "anger": 4.07237755e-09,
#       "contempt": 2.69491235e-10,
#       "disgust": 4.068019e-07,
#       "fear": 9.240599e-13,
#       "happiness": 0.9999996,
#       "neutral": 6.21527452e-09,
#       "sadness": 9.347618e-09,
#       "surprise": 1.18115268e-10
#     }
#   },
#   {
#     "faceRectangle": {
#       "height": 117,
#       "left": 697,
#       "top": 8,
#       "width": 117
#     },
#     "scores": {
#       "anger": 0.0115646394,
#       "contempt": 0.010189712,
#       "disgust": 0.102803655,
#       "fear": 0.0006363937,
#       "happiness": 0.005456246,
#       "neutral": 0.8412396,
#       "sadness": 0.00920655,
#       "surprise": 0.01890323
#     }
#   },
#   {
#     "faceRectangle": {
#       "height": 115,
#       "left": 1278,
#       "top": 62,
#       "width": 115
#     },
#     "scores": {
#       "anger": 0.0012051675,
#       "contempt": 0.008492738,
#       "disgust": 0.00129800651,
#       "fear": 3.41597934e-06,
#       "happiness": 0.00586063974,
#       "neutral": 0.977827966,
#       "sadness": 0.005258195,
#       "surprise": 5.3866228e-05
#     }
#   },
#   {
#     "faceRectangle": {
#       "height": 111,
#       "left": 1748,
#       "top": 234,
#       "width": 111
#     },
#     "scores": {
#       "anger": 8.962425e-05,
#       "contempt": 0.00338870753,
#       "disgust": 0.000337504374,
#       "fear": 1.4111436e-05,
#       "happiness": 0.402313083,
#       "neutral": 0.5880899,
#       "sadness": 0.004436236,
#       "surprise": 0.001330867
#     }
#   },
#   {
#     "faceRectangle": {
#       "height": 102,
#       "left": 1769,
#       "top": 137,
#       "width": 102
#     },
#     "scores": {
#       "anger": 0.00595768075,
#       "contempt": 0.000257451436,
#       "disgust": 7.537343e-05,
#       "fear": 1.37292436e-05,
#       "happiness": 0.000723931,
#       "neutral": 0.987351537,
#       "sadness": 0.00554071646,
#       "surprise": 7.958424e-05
#     }
#   }
# ]
