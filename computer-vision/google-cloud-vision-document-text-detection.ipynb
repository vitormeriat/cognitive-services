# %% [markdown]
# # Document Text Detection
#
# This demo use **Google Cloud Platform Vision API**.

# %%
import time 
import urllib
import requests
import cv2
import operator
import numpy as np
from __future__ import print_function
import matplotlib.pyplot as plt
# %matplotlib inline 

_url = 'https://vision.googleapis.com/v1/images:annotate'
_key = '__KEY__'

# %%
def processRequest( json, data, headers, params ):

    retries = 0
    result = None

    while True:

        response = requests.request( 'post', _url, json = json, data = data, headers = headers, params = params )

        if response.status_code == 429: 

            print( "Message: %s" % ( response.json()['error']['message'] ) )

            if retries <= _maxNumRetries: 
                time.sleep(1) 
                retries += 1
                continue
            else: 
                print( 'Error: failed after retrying!' )
                break

        elif response.status_code == 200 or response.status_code == 201:

            if 'content-length' in response.headers and int(response.headers['content-length']) == 0: 
                result = None 
            elif 'content-type' in response.headers and isinstance(response.headers['content-type'], str): 
                if 'application/json' in response.headers['content-type'].lower(): 
                    result = response.json() if response.content else None 
                elif 'image' in response.headers['content-type'].lower(): 
                    result = response.content
        else:
            print( "Error code: %d" % ( response.status_code ) )
            print( "Message: %s" % ( response.json()['error']['message'] ) )

        break
        
    return result

# %%
from IPython.display import Image as ipImage, display

urlImage = 'http://www.folgerdigitaltexts.org/Images/grab6.png'

img = ipImage(url=urlImage)
display(img)
# Out:
# <img src="http://www.folgerdigitaltexts.org/Images/grab6.png"/>

# %%
headers = dict()
headers['Content-Type'] = 'application/json' 

json = {
  "requests": [
    {
      "image": {
        "source": {
          "imageUri": urlImage
        }
      },
      "features": [
        {
          "type": "DOCUMENT_TEXT_DETECTION"
        }
      ]
    }
  ]
}

data = None
params = urllib.parse.urlencode({
    'key': _key
})

result = processRequest( json, data, headers, params )

# %%
import json

print(json.dumps(result, indent=2, sort_keys=True))
# Out:
# {
#   "responses": [
#     {
#       "fullTextAnnotation": {
#         "pages": [
#           {
#             "blocks": [
#               {
#                 "blockType": "TEXT",
#                 "boundingBox": {
#                   "vertices": [
#                     {
#                       "x": 103,
#                       "y": 25
#                     },
#                     {
#                       "x": 508,
#                       "y": 26
#                     },
#                     {
#                       "x": 508,
#                       "y": 186
#                     },
#                     {
#                       "x": 103,
#                       "y": 185
#                     }
#                   ]
#                 },
#                 "paragraphs": [
#                   {
#                     "boundingBox": {
#                       "vertices": [
#                         {
#                           "x": 103,
#                           "y": 25
#                         },
#                         {
#                           "x": 508,
#                           "y": 26
#                         },
#                         {
#                           "x": 508,
#                           "y": 129
#                         },
#                         {
#                           "x": 103,
#                           "y": 128
#                         }
#                       ]
#                     },
#                     "property": {
#                       "detectedLanguages": [
#                         {
#                           "languageCode": "en"
#                         }
#                       ]
#                     },
#                     "words": [
#                       {
#                         "boundingBox": {
#                           "vertices": [
#                             {
#                               "x": 188,
#                               "y": 25
#                             },
#                             {
#                               "x": 262,
#                               "y": 25
#                             },
#                             {
#                               "x": 262,
#                               "y": 61
#                             },
#                             {
#                               "x": 188,
#                               "y": 61
#                             }
#                           ]
#                         },
#                         "property": {
#                           "detectedLanguages": [
#                             {
#                               "languageCode": "en"
#                             }
#                           ]
#                         },
#                         "symbols": [
#                           {
#                             "boundingBox": {
#                               "vertices": [
#                                 {
#                                   "x": 188,
#                                   "y": 25
#                                 },
#                                 {
#                                   "x": 204,
#                                   "y": 25
#                                 },
#                                 {
#                                   "x": 204,
#                                   "y": 61
#                                 },
#                                 {
#                                   "x": 188,
#                                   "y": 61
#                                 }
#                               ]
#                             },
#                             "property": {
#                               "detectedLanguages": [
#                                 {
#                                   "languageCode": "en"
#                                 }
#                               ]
#                             },
#                             "text": "P"
#                           },
#                           {
#                             "boundingBox": {
#                               "vertices": [
#                                 {
#                                   "x": 209,
#                                   "y": 25
#                                 },
#                                 {
#                                   "x": 222,
#                                   "y": 25
#                                 },
#                                 {
#                                   "x": 222,
#                                   "y": 61
#                                 },
#                                 {
#                                   "x": 209,
#                                   "y": 61
#                                 }
#                               ]
#                             },
#                             "property": {
#                               "detectedLanguages": [
#                                 {
#                                   "languageCode": "en"
#                                 }
#                               ]
#                             },
#                             "text": "i"
#                           },
#                           {
#                             "boundingBox": {
#                               "vertices": [
#                                 {
#                                   "x": 223,
#                                   "y": 25
#                                 },
#                                 {
#                                   "x": 237,
#                                   "y": 25
#                                 },
#                                 {
#                                   "x": 237,
#                                   "y": 61
#                                 },
#                                 {
#                                   "x": 223,
#                                   "y": 61
#                                 }
#                               ]
#                             },
#                             "property": {
#                               "detectedLanguages": [
#                                 {
#                                   "languageCode": "en"
#                                 }
#                               ]
#                             },
#                             "text": "c"
#                           },
#                           {
#                             "boundingBox": {
#                               "vertices": [
#                                 {
#                                   "x": 242,
#                                   "y": 25
#                                 },
#                                 {
#                                   "x": 262,
#                                   "y": 25
#                                 },
#                                 {
#                                   "x": 262,
#                                   "y": 61
#                                 },
#                                 {
#                                   "x": 242,
#                                   "y": 61
#                                 }
#                               ]
#                             },
#                             "property": {
#                               "detectedBreak": {
#                                 "type": "SPACE"
#                               },
#                               "detectedLanguages": [
#                                 {
#                                   "languageCode": "en"
#                                 }
#                               ]
#                             },
#                             "text": "k"
#                           }
#                         ]
#                       },
#                       {
#                         "boundingBox": {
#                           "vertices": [
#                             {
#                               "x": 278,
#                               "y": 25
#                             },
#                             {
#                               "x": 291,
#                               "y": 25
#                             },
#                             {
#                               "x": 291,
#                               "y": 61
#                             },
#                             {
#                               "x": 278,
#                               "y": 61
#                             }
#                           ]
#                         },
#                         "property": {
#                           "detectedLanguages": [
#                             {
#                               "languageCode": "en"
#                             }
#                           ]
#                         },
#                         "symbols": [
#                           {
#                             "boundingBox": {
#                               "vertices": [
#                                 {
#                                   "x": 278,
#                                   "y": 25
#                                 },
#                                 {
#                                   "x": 291,
#                                   "y": 25
#                                 },
#                                 {
#                                   "x": 291,
#                                   "y": 61
#                                 },
#                                 {
#                                   "x": 278,
#                                   "y": 61
#                                 }
#                               ]
#                             },
#                             "property": {
#                               "detectedBreak": {
#                                 "type": "SPACE"
#                               },
#                               "detectedLanguages": [
#                                 {
#                                   "languageCode": "en"
#                                 }
#                               ]
#                             },
#                             "text": "a"
#                           }
#                         ]
#                       },
#                       {
#                         "boundingBox": {
#                           "vertices": [
#                             {
#                               "x": 306,
#                               "y": 25
#                             },
#                             {
#                               "x": 374,
#                               "y": 25
#                             },
#                             {
#                               "x": 374,
#                               "y": 61
#                             },
#                             {
#                               "x": 306,
#                               "y": 61
#                             }
#                           ]
#                         },
#                         "property": {
#                           "detectedLanguages": [
#                             {
#                               "languageCode": "en"
#                             }
#                           ]
#                         },
#                         "symbols": [
#                           {
#                             "boundingBox": {
#                               "vertices": [
#                                 {
#                                   "x": 306,
#                                   "y": 25
#                                 },
#                                 {
#                                   "x": 321,
#                                   "y": 25
#                                 },
#                                 {
#                                   "x": 321,
#                                   "y": 61
#                                 },
#                                 {
#                                   "x": 306,
#                                   "y": 61
#                                 }
#                               ]
#                             },
#                             "property": {
#                               "detectedLanguages": [
#                                 {
#                                   "languageCode": "en"
#                                 }
#                               ]
#                             },
#                             "text": "t"
#                           },
#                           {
#                             "boundingBox": {
#                               "vertices": [
#                                 {
#                                   "x": 325,
#                                   "y": 25
#                                 },
#                                 {
#                                   "x": 341,
#                                   "y": 25
#                                 },
#                                 {
#                                   "x": 341,
#                                   "y": 61
#                                 },
#                                 {
#                                   "x": 325,
#                                   "y": 61
#                                 }
#                               ]
#                             },
#                             "property": {
#                               "detectedLanguages": [
#                                 {
#                                   "languageCode": "en"
#                                 }
#                               ]
#                             },
#                             "text": "e"
#                           },
#                           {
#                             "boundingBox": {
#                               "vertices": [
#                                 {
#                                   "x": 346,
#                                   "y": 25
#                                 },
#                                 {
#                                   "x": 360,
#                                   "y": 25
#                                 },
#                                 {
#                                   "x": 360,
#                                   "y": 61
#                                 },
#                                 {
#                                   "x": 346,
#                                   "y": 61
#                                 }
#                               ]
#                             },
#                             "property": {
#                               "detectedLanguages": [
#                                 {
#                                   "languageCode": "en"
#                                 }
#                               ]
#                             },
#                             "text": "x"
#                           },
#                           {
#                             "boundingBox": {
#                               "vertices": [
#                                 {
#                                   "x": 362,
#                                   "y": 25
#                                 },
#                                 {
#                                   "x": 374,
#                                   "y": 25
#                                 },
#                                 {
#                                   "x": 374,
#                                   "y": 61
#                                 },
#                                 {
#                                   "x": 362,
#                                   "y": 61
#                                 }
#                               ]
#                             },
#                             "property": {
#                               "detectedLanguages": [
#                                 {
#                                   "languageCode": "en"
#                                 }
#                               ]
#                             },
#                             "text": "t"
#                           }
#                         ]
#                       },
#                       {
#                         "boundingBox": {
#                           "vertices": [
#                             {
#                               "x": 376,
#                               "y": 25
#                             },
#                             {
#                               "x": 389,
#                               "y": 25
#                             },
#                             {
#                               "x": 389,
#                               "y": 61
#                             },
#                             {
#                               "x": 376,
#                               "y": 61
#                             }
#                           ]
#                         },
#                         "property": {
#                           "detectedLanguages": [
#                             {
#                               "languageCode": "en"
#                             }
#                           ]
#                         },
#                         "symbols": [
#                           {
#                             "boundingBox": {
#                               "vertices": [
#                                 {
#                                   "x": 376,
#                                   "y": 25
#                                 },
#                                 {
#                                   "x": 389,
#                                   "y": 25
#                                 },
#                                 {
#                                   "x": 389,
#                                   "y": 61
#                                 },
#                                 {
#                                   "x": 376,
#                                   "y": 61
#                                 }
#                               ]
#                             },
#                             "property": {
#                               "detectedBreak": {
#                                 "type": "SPACE"
#                               },
#                               "detectedLanguages": [
#                                 {
#                                   "languageCode": "en"
#                                 }
#                               ]
#                             },
#                             "text": ","
#                           }
#                         ]
#                       },
#                       {
#                         "boundingBox": {
#                           "vertices": [
#                             {
#                               "x": 410,
#                               "y": 25
#                             },
#                             {
#                               "x": 470,
#                               "y": 25
#                             },
#                             {
#                               "x": 470,
#                               "y": 61
#                             },
#                             {
#                               "x": 410,
#                               "y": 61
#                             }
#                           ]
#                         },
#                         "property": {
#                           "detectedLanguages": [
#                             {
#                               "languageCode": "en"
#                             }
#                           ]
#                         },
#                         "symbols": [
#                           {
#                             "boundingBox": {
#                               "vertices": [
#                                 {
#                                   "x": 410,
#                                   "y": 25
#                                 },
#                                 {
#                                   "x": 414,
#                                   "y": 25
#                                 },
#                                 {
#                                   "x": 414,
#                                   "y": 61
#                                 },
#                                 {
#                                   "x": 410,
#                                   "y": 61
#                                 }
#                               ]
#                             },
#                             "property": {
#                               "detectedLanguages": [
#                                 {
#                                   "languageCode": "en"
#                                 }
#                               ]
#                             },
#                             "text": "f"
#                           },
#                           {
#                             "boundingBox": {
#                               "vertices": [
#                                 {
#                                   "x": 413,
#                                   "y": 25
#                                 },
#                                 {
#                                   "x": 426,
#                                   "y": 25
#                                 },
#                                 {
#                                   "x": 426,
#                                   "y": 61
#                                 },
#                                 {
#                                   "x": 413,
#                                   "y": 61
#                                 }
#                               ]
#                             },
#                             "property": {
#                               "detectedLanguages": [
#                                 {
#                                   "languageCode": "en"
#                                 }
#                               ]
#                             },
#                             "text": "i"
#                           },
#                           {
#                             "boundingBox": {
#                               "vertices": [
#                                 {
#                                   "x": 428,
#                                   "y": 25
#                                 },
#                                 {
#                                   "x": 444,
#                                   "y": 25
#                                 },
#                                 {
#                                   "x": 444,
#                                   "y": 61
#                                 },
#                                 {
#                                   "x": 428,
#                                   "y": 61
#                                 }
#                               ]
#                             },
#                             "property": {
#                               "detectedLanguages": [
#                                 {
#                                   "languageCode": "en"
#                                 }
#                               ]
#                             },
#                             "text": "n"
#                           },
#                           {
#                             "boundingBox": {
#                               "vertices": [
#                                 {
#                                   "x": 451,
#                                   "y": 25
#                                 },
#                                 {
#                                   "x": 470,
#                                   "y": 25
#                                 },
#                                 {
#                                   "x": 470,
#                                   "y": 61
#                                 },
#                                 {
#                                   "x": 451,
#                                   "y": 61
#                                 }
#                               ]
#                             },
#                             "property": {
#                               "detectedBreak": {
#                                 "type": "SPACE"
#                               },
#                               "detectedLanguages": [
#                                 {
#                                   "languageCode": "en"
#                                 }
#                               ]
#                             },
#                             "text": "d"
#                           }
#                         ]
#                       },
#                       {
#                         "boundingBox": {
#                           "vertices": [
#                             {
#                               "x": 488,
#                               "y": 25
#                             },
#                             {
#                               "x": 501,
#                               "y": 25
#                             },
#                             {
#                               "x": 501,
#                               "y": 61
#                             },
#                             {
#                               "x": 488,
#                               "y": 61
#                             }
#                           ]
#                         },
#                         "property": {
#                           "detectedLanguages": [
#                             {
#                               "languageCode": "en"
#                             }
#                           ]
#                         },
#                         "symbols": [
#                           {
#                             "boundingBox": {
#                               "vertices": [
#                                 {
#                                   "x": 488,
#                                   "y": 25
#                                 },
#                                 {
#                                   "x": 501,
#                                   "y": 25
#                                 },
#                                 {
#                                   "x": 501,
#                                   "y": 61
#                                 },
#                                 {
#                                   "x": 488,
#                                   "y": 61
#                                 }
#                               ]
#                             },
#                             "property": {
#                               "detectedBreak": {
#                                 "type": "EOL_SURE_SPACE"
#                               },
#                               "detectedLanguages": [
#                                 {
#                                   "languageCode": "en"
#                                 }
#                               ]
#                             },
#                             "text": "a"
#                           }
#                         ]
#                       },
#                       {
#                         "boundingBox": {
#                           "vertices": [
#                             {
#                               "x": 103,
#                               "y": 97
#                             },
#                             {
#                               "x": 217,
#                               "y": 97
#                             },
#                             {
#                               "x": 217,
#                               "y": 128
#                             },
#                             {
#                               "x": 103,
#                               "y": 128
#                             }
#                           ]
#                         },
#                         "property": {
#                           "detectedLanguages": [
#                             {
#                               "languageCode": "en"
#                             }
#                           ]
#                         },
#                         "symbols": [
#                           {
#                             "boundingBox": {
#                               "vertices": [
#                                 {
#                                   "x": 103,
#                                   "y": 97
#                                 },
#                                 {
#                                   "x": 123,
#                                   "y": 97
#                                 },
#                                 {
#                                   "x": 123,
#                                   "y": 128
#                                 },
#                                 {
#                                   "x": 103,
#                                   "y": 128
#                                 }
#                               ]
#                             },
#                             "property": {
#                               "detectedLanguages": [
#                                 {
#                                   "languageCode": "en"
#                                 }
#                               ]
#                             },
#                             "text": "p"
#                           },
#                           {
#                             "boundingBox": {
#                               "vertices": [
#                                 {
#                                   "x": 129,
#                                   "y": 97
#                                 },
#                                 {
#                                   "x": 148,
#                                   "y": 97
#                                 },
#                                 {
#                                   "x": 148,
#                                   "y": 128
#                                 },
#                                 {
#                                   "x": 129,
#                                   "y": 128
#                                 }
#                               ]
#                             },
#                             "property": {
#                               "detectedLanguages": [
#                                 {
#                                   "languageCode": "en"
#                                 }
#                               ]
#                             },
#                             "text": "h"
#                           },
#                           {
#                             "boundingBox": {
#                               "vertices": [
#                                 {
#                                   "x": 152,
#                                   "y": 97
#                                 },
#                                 {
#                                   "x": 167,
#                                   "y": 97
#                                 },
#                                 {
#                                   "x": 167,
#                                   "y": 128
#                                 },
#                                 {
#                                   "x": 152,
#                                   "y": 128
#                                 }
#                               ]
#                             },
#                             "property": {
#                               "detectedLanguages": [
#                                 {
#                                   "languageCode": "en"
#                                 }
#                               ]
#                             },
#                             "text": "r"
#                           },
#                           {
#                             "boundingBox": {
#                               "vertices": [
#                                 {
#                                   "x": 170,
#                                   "y": 97
#                                 },
#                                 {
#                                   "x": 183,
#                                   "y": 97
#                                 },
#                                 {
#                                   "x": 183,
#                                   "y": 128
#                                 },
#                                 {
#                                   "x": 170,
#                                   "y": 128
#                                 }
#                               ]
#                             },
#                             "property": {
#                               "detectedLanguages": [
#                                 {
#                                   "languageCode": "en"
#                                 }
#                               ]
#                             },
#                             "text": "a"
#                           },
#                           {
#                             "boundingBox": {
#                               "vertices": [
#                                 {
#                                   "x": 186,
#                                   "y": 97
#                                 },
#                                 {
#                                   "x": 200,
#                                   "y": 97
#                                 },
#                                 {
#                                   "x": 200,
#                                   "y": 128
#                                 },
#                                 {
#                                   "x": 186,
#                                   "y": 128
#                                 }
#                               ]
#                             },
#                             "property": {
#                               "detectedLanguages": [
#                                 {
#                                   "languageCode": "en"
#                                 }
#                               ]
#                             },
#                             "text": "s"
#                           },
#                           {
#                             "boundingBox": {
#                               "vertices": [
#                                 {
#                                   "x": 203,
#                                   "y": 97
#                                 },
#                                 {
#                                   "x": 217,
#                                   "y": 97
#                                 },
#                                 {
#                                   "x": 217,
#                                   "y": 128
#                                 },
#                                 {
#                                   "x": 203,
#                                   "y": 128
#                                 }
#                               ]
#                             },
#                             "property": {
#                               "detectedLanguages": [
#                                 {
#                                   "languageCode": "en"
#                                 }
#                               ]
#                             },
#                             "text": "e"
#                           }
#                         ]
#                       },
#                       {
#                         "boundingBox": {
#                           "vertices": [
#                             {
#                               "x": 221,
#                               "y": 97
#                             },
#                             {
#                               "x": 232,
#                               "y": 97
#                             },
#                             {
#                               "x": 232,
#                               "y": 128
#                             },
#                             {
#                               "x": 221,
#                               "y": 128
#                             }
#                           ]
#                         },
#                         "property": {
#                           "detectedLanguages": [
#                             {
#                               "languageCode": "en"
#                             }
#                           ]
#                         },
#                         "symbols": [
#                           {
#                             "boundingBox": {
#                               "vertices": [
#                                 {
#                                   "x": 221,
#                                   "y": 97
#                                 },
#                                 {
#                                   "x": 232,
#                                   "y": 97
#                                 },
#                                 {
#                                   "x": 232,
#                                   "y": 128
#                                 },
#                                 {
#                                   "x": 221,
#                                   "y": 128
#                                 }
#                               ]
#                             },
#                             "property": {
#                               "detectedBreak": {
#                                 "type": "SPACE"
#                               },
#                               "detectedLanguages": [
#                                 {
#                                   "languageCode": "en"
#                                 }
#                               ]
#                             },
#                             "text": ","
#                           }
#                         ]
#                       },
#                       {
#                         "boundingBox": {
#                           "vertices": [
#                             {
#                               "x": 247,
#                               "y": 97
#                             },
#                             {
#                               "x": 332,
#                               "y": 97
#                             },
#                             {
#                               "x": 332,
#                               "y": 128
#                             },
#                             {
#                               "x": 247,
#                               "y": 128
#                             }
#                           ]
#                         },
#                         "property": {
#                           "detectedLanguages": [
#                             {
#                               "languageCode": "en"
#                             }
#                           ]
#                         },
#                         "symbols": [
#                           {
#                             "boundingBox": {
#                               "vertices": [
#                                 {
#                                   "x": 247,
#                                   "y": 97
#                                 },
#                                 {
#                                   "x": 257,
#                                   "y": 97
#                                 },
#                                 {
#                                   "x": 257,
#                                   "y": 128
#                                 },
#                                 {
#                                   "x": 247,
#                                   "y": 128
#                                 }
#                               ]
#                             },
#                             "property": {
#                               "detectedLanguages": [
#                                 {
#                                   "languageCode": "en"
#                                 }
#                               ]
#                             },
#                             "text": "l"
#                           },
#                           {
#                             "boundingBox": {
#                               "vertices": [
#                                 {
#                                   "x": 258,
#                                   "y": 97
#                                 },
#                                 {
#                                   "x": 272,
#                                   "y": 97
#                                 },
#                                 {
#                                   "x": 272,
#                                   "y": 128
#                                 },
#                                 {
#                                   "x": 258,
#                                   "y": 128
#                                 }
#                               ]
#                             },
#                             "property": {
#                               "detectedLanguages": [
#                                 {
#                                   "languageCode": "en"
#                                 }
#                               ]
#                             },
#                             "text": "e"
#                           },
#                           {
#                             "boundingBox": {
#                               "vertices": [
#                                 {
#                                   "x": 278,
#                                   "y": 97
#                                 },
#                                 {
#                                   "x": 293,
#                                   "y": 97
#                                 },
#                                 {
#                                   "x": 293,
#                                   "y": 128
#                                 },
#                                 {
#                                   "x": 278,
#                                   "y": 128
#                                 }
#                               ]
#                             },
#                             "property": {
#                               "detectedLanguages": [
#                                 {
#                                   "languageCode": "en"
#                                 }
#                               ]
#                             },
#                             "text": "a"
#                           },
#                           {
#                             "boundingBox": {
#                               "vertices": [
#                                 {
#                                   "x": 295,
#                                   "y": 97
#                                 },
#                                 {
#                                   "x": 310,
#                                   "y": 97
#                                 },
#                                 {
#                                   "x": 310,
#                                   "y": 128
#                                 },
#                                 {
#                                   "x": 295,
#                                   "y": 128
#                                 }
#                               ]
#                             },
#                             "property": {
#                               "detectedLanguages": [
#                                 {
#                                   "languageCode": "en"
#                                 }
#                               ]
#                             },
#                             "text": "r"
#                           },
#                           {
#                             "boundingBox": {
#                               "vertices": [
#                                 {
#                                   "x": 315,
#                                   "y": 97
#                                 },
#                                 {
#                                   "x": 332,
#                                   "y": 97
#                                 },
#                                 {
#                                   "x": 332,
#                                   "y": 128
#                                 },
#                                 {
#                                   "x": 315,
#                                   "y": 128
#                                 }
#                               ]
#                             },
#                             "property": {
#                               "detectedBreak": {
#                                 "type": "SPACE"
#                               },
#                               "detectedLanguages": [
#                                 {
#                                   "languageCode": "en"
#                                 }
#                               ]
#                             },
#                             "text": "n"
#                           }
#                         ]
#                       },
#                       {
#                         "boundingBox": {
#                           "vertices": [
#                             {
#                               "x": 358,
#                               "y": 97
#                             },
#                             {
#                               "x": 442,
#                               "y": 97
#                             },
#                             {
#                               "x": 442,
#                               "y": 128
#                             },
#                             {
#                               "x": 358,
#                               "y": 128
#                             }
#                           ]
#                         },
#                         "property": {
#                           "detectedLanguages": [
#                             {
#                               "languageCode": "en"
#                             }
#                           ]
#                         },
#                         "symbols": [
#                           {
#                             "boundingBox": {
#                               "vertices": [
#                                 {
#                                   "x": 358,
#                                   "y": 97
#                                 },
#                                 {
#                                   "x": 381,
#                                   "y": 97
#                                 },
#                                 {
#                                   "x": 381,
#                                   "y": 128
#                                 },
#                                 {
#                                   "x": 358,
#                                   "y": 128
#                                 }
#                               ]
#                             },
#                             "property": {
#                               "detectedLanguages": [
#                                 {
#                                   "languageCode": "en"
#                                 }
#                               ]
#                             },
#                             "text": "m"
#                           },
#                           {
#                             "boundingBox": {
#                               "vertices": [
#                                 {
#                                   "x": 390,
#                                   "y": 97
#                                 },
#                                 {
#                                   "x": 408,
#                                   "y": 97
#                                 },
#                                 {
#                                   "x": 408,
#                                   "y": 128
#                                 },
#                                 {
#                                   "x": 390,
#                                   "y": 128
#                                 }
#                               ]
#                             },
#                             "property": {
#                               "detectedLanguages": [
#                                 {
#                                   "languageCode": "en"
#                                 }
#                               ]
#                             },
#                             "text": "o"
#                           },
#                           {
#                             "boundingBox": {
#                               "vertices": [
#                                 {
#                                   "x": 410,
#                                   "y": 97
#                                 },
#                                 {
#                                   "x": 426,
#                                   "y": 97
#                                 },
#                                 {
#                                   "x": 426,
#                                   "y": 128
#                                 },
#                                 {
#                                   "x": 410,
#                                   "y": 128
#                                 }
#                               ]
#                             },
#                             "property": {
#                               "detectedLanguages": [
#                                 {
#                                   "languageCode": "en"
#                                 }
#                               ]
#                             },
#                             "text": "r"
#                           },
#                           {
#                             "boundingBox": {
#                               "vertices": [
#                                 {
#                                   "x": 428,
#                                   "y": 97
#                                 },
#                                 {
#                                   "x": 442,
#                                   "y": 97
#                                 },
# ...
#                                   "y": 185
#                                 },
#                                 {
#                                   "x": 371,
#                                   "y": 185
#                                 }
#                               ]
#                             },
#                             "property": {
#                               "detectedLanguages": [
#                                 {
#                                   "languageCode": "en"
#                                 }
#                               ]
#                             },
#                             "text": "r"
#                           },
#                           {
#                             "boundingBox": {
#                               "vertices": [
#                                 {
#                                   "x": 389,
#                                   "y": 152
#                                 },
#                                 {
#                                   "x": 403,
#                                   "y": 152
#                                 },
#                                 {
#                                   "x": 403,
#                                   "y": 185
#                                 },
#                                 {
#                                   "x": 389,
#                                   "y": 185
#                                 }
#                               ]
#                             },
#                             "property": {
#                               "detectedLanguages": [
#                                 {
#                                   "languageCode": "en"
#                                 }
#                               ]
#                             },
#                             "text": "e"
#                           },
#                           {
#                             "boundingBox": {
#                               "vertices": [
#                                 {
#                                   "x": 406,
#                                   "y": 152
#                                 },
#                                 {
#                                   "x": 422,
#                                   "y": 152
#                                 },
#                                 {
#                                   "x": 422,
#                                   "y": 185
#                                 },
#                                 {
#                                   "x": 406,
#                                   "y": 185
#                                 }
#                               ]
#                             },
#                             "property": {
#                               "detectedLanguages": [
#                                 {
#                                   "languageCode": "en"
#                                 }
#                               ]
#                             },
#                             "text": "a"
#                           },
#                           {
#                             "boundingBox": {
#                               "vertices": [
#                                 {
#                                   "x": 428,
#                                   "y": 152
#                                 },
#                                 {
#                                   "x": 444,
#                                   "y": 152
#                                 },
#                                 {
#                                   "x": 444,
#                                   "y": 185
#                                 },
#                                 {
#                                   "x": 428,
#                                   "y": 185
#                                 }
#                               ]
#                             },
#                             "property": {
#                               "detectedLanguages": [
#                                 {
#                                   "languageCode": "en"
#                                 }
#                               ]
#                             },
#                             "text": "d"
#                           },
#                           {
#                             "boundingBox": {
#                               "vertices": [
#                                 {
#                                   "x": 447,
#                                   "y": 152
#                                 },
#                                 {
#                                   "x": 461,
#                                   "y": 152
#                                 },
#                                 {
#                                   "x": 461,
#                                   "y": 185
#                                 },
#                                 {
#                                   "x": 447,
#                                   "y": 185
#                                 }
#                               ]
#                             },
#                             "property": {
#                               "detectedLanguages": [
#                                 {
#                                   "languageCode": "en"
#                                 }
#                               ]
#                             },
#                             "text": "i"
#                           },
#                           {
#                             "boundingBox": {
#                               "vertices": [
#                                 {
#                                   "x": 464,
#                                   "y": 152
#                                 },
#                                 {
#                                   "x": 480,
#                                   "y": 152
#                                 },
#                                 {
#                                   "x": 480,
#                                   "y": 185
#                                 },
#                                 {
#                                   "x": 464,
#                                   "y": 185
#                                 }
#                               ]
#                             },
#                             "property": {
#                               "detectedLanguages": [
#                                 {
#                                   "languageCode": "en"
#                                 }
#                               ]
#                             },
#                             "text": "n"
#                           },
#                           {
#                             "boundingBox": {
#                               "vertices": [
#                                 {
#                                   "x": 486,
#                                   "y": 152
#                                 },
#                                 {
#                                   "x": 508,
#                                   "y": 152
#                                 },
#                                 {
#                                   "x": 508,
#                                   "y": 185
#                                 },
#                                 {
#                                   "x": 486,
#                                   "y": 185
#                                 }
#                               ]
#                             },
#                             "property": {
#                               "detectedBreak": {
#                                 "type": "LINE_BREAK"
#                               },
#                               "detectedLanguages": [
#                                 {
#                                   "languageCode": "en"
#                                 }
#                               ]
#                             },
#                             "text": "g"
#                           }
#                         ]
#                       }
#                     ]
#                   }
#                 ],
#                 "property": {
#                   "detectedLanguages": [
#                     {
#                       "languageCode": "en"
#                     }
#                   ]
#                 }
#               }
#             ],
#             "height": 216,
#             "property": {
#               "detectedLanguages": [
#                 {
#                   "languageCode": "en"
#                 }
#               ]
#             },
#             "width": 720
#           }
#         ],
#         "text": "Pick a text, find a\nphrase, learn more, or\njust start reading\n"
#       },
#       "textAnnotations": [
#         {
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 103,
#                 "y": 25
#               },
#               {
#                 "x": 508,
#                 "y": 25
#               },
#               {
#                 "x": 508,
#                 "y": 185
#               },
#               {
#                 "x": 103,
#                 "y": 185
#               }
#             ]
#           },
#           "description": "Pick a text, find a\nphrase, learn more, or\njust start reading\n",
#           "locale": "en"
#         },
#         {
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 188,
#                 "y": 25
#               },
#               {
#                 "x": 262,
#                 "y": 25
#               },
#               {
#                 "x": 262,
#                 "y": 61
#               },
#               {
#                 "x": 188,
#                 "y": 61
#               }
#             ]
#           },
#           "description": "Pick"
#         },
#         {
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 278,
#                 "y": 25
#               },
#               {
#                 "x": 291,
#                 "y": 25
#               },
#               {
#                 "x": 291,
#                 "y": 61
#               },
#               {
#                 "x": 278,
#                 "y": 61
#               }
#             ]
#           },
#           "description": "a"
#         },
#         {
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 306,
#                 "y": 25
#               },
#               {
#                 "x": 374,
#                 "y": 25
#               },
#               {
#                 "x": 374,
#                 "y": 61
#               },
#               {
#                 "x": 306,
#                 "y": 61
#               }
#             ]
#           },
#           "description": "text"
#         },
#         {
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 376,
#                 "y": 25
#               },
#               {
#                 "x": 389,
#                 "y": 25
#               },
#               {
#                 "x": 389,
#                 "y": 61
#               },
#               {
#                 "x": 376,
#                 "y": 61
#               }
#             ]
#           },
#           "description": ","
#         },
#         {
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 410,
#                 "y": 25
#               },
#               {
#                 "x": 470,
#                 "y": 25
#               },
#               {
#                 "x": 470,
#                 "y": 61
#               },
#               {
#                 "x": 410,
#                 "y": 61
#               }
#             ]
#           },
#           "description": "find"
#         },
#         {
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 488,
#                 "y": 25
#               },
#               {
#                 "x": 501,
#                 "y": 25
#               },
#               {
#                 "x": 501,
#                 "y": 61
#               },
#               {
#                 "x": 488,
#                 "y": 61
#               }
#             ]
#           },
#           "description": "a"
#         },
#         {
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 103,
#                 "y": 97
#               },
#               {
#                 "x": 217,
#                 "y": 97
#               },
#               {
#                 "x": 217,
#                 "y": 128
#               },
#               {
#                 "x": 103,
#                 "y": 128
#               }
#             ]
#           },
#           "description": "phrase"
#         },
#         {
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 221,
#                 "y": 97
#               },
#               {
#                 "x": 232,
#                 "y": 97
#               },
#               {
#                 "x": 232,
#                 "y": 128
#               },
#               {
#                 "x": 221,
#                 "y": 128
#               }
#             ]
#           },
#           "description": ","
#         },
#         {
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 247,
#                 "y": 97
#               },
#               {
#                 "x": 332,
#                 "y": 97
#               },
#               {
#                 "x": 332,
#                 "y": 128
#               },
#               {
#                 "x": 247,
#                 "y": 128
#               }
#             ]
#           },
#           "description": "learn"
#         },
#         {
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 358,
#                 "y": 97
#               },
#               {
#                 "x": 442,
#                 "y": 97
#               },
#               {
#                 "x": 442,
#                 "y": 128
#               },
#               {
#                 "x": 358,
#                 "y": 128
#               }
#             ]
#           },
#           "description": "more"
#         },
#         {
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 444,
#                 "y": 97
#               },
#               {
#                 "x": 455,
#                 "y": 97
#               },
#               {
#                 "x": 455,
#                 "y": 128
#               },
#               {
#                 "x": 444,
#                 "y": 128
#               }
#             ]
#           },
#           "description": ","
#         },
#         {
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 470,
#                 "y": 97
#               },
#               {
#                 "x": 508,
#                 "y": 97
#               },
#               {
#                 "x": 508,
#                 "y": 128
#               },
#               {
#                 "x": 470,
#                 "y": 128
#               }
#             ]
#           },
#           "description": "or"
#         },
#         {
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 193,
#                 "y": 152
#               },
#               {
#                 "x": 266,
#                 "y": 152
#               },
#               {
#                 "x": 266,
#                 "y": 185
#               },
#               {
#                 "x": 193,
#                 "y": 185
#               }
#             ]
#           },
#           "description": "just"
#         },
#         {
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 276,
#                 "y": 152
#               },
#               {
#                 "x": 356,
#                 "y": 152
#               },
#               {
#                 "x": 356,
#                 "y": 185
#               },
#               {
#                 "x": 276,
#                 "y": 185
#               }
#             ]
#           },
#           "description": "start"
#         },
#         {
#           "boundingPoly": {
#             "vertices": [
#               {
#                 "x": 371,
#                 "y": 152
#               },
#               {
#                 "x": 508,
#                 "y": 152
#               },
#               {
#                 "x": 508,
#                 "y": 185
#               },
#               {
#                 "x": 371,
#                 "y": 185
#               }
#             ]
#           },
#           "description": "reading"
#         }
#       ]
#     }
#   ]
# }
