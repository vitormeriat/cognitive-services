# %% [markdown]
# # OCR
#
# This demo use **Microsoft Azure Cognitive Services**.

# %%
import time 
import urllib
import requests
import cv2
import operator
import numpy as np
from __future__ import print_function
import matplotlib.pyplot as plt
# %matplotlib inline 

_url = 'https://westus.api.cognitive.microsoft.com/vision/v1.0/ocr'
_key = '__KEY__'
_maxNumRetries = 10

# %%
def processRequest( json, data, headers, params ):

    retries = 0
    result = None

    while True:

        response = requests.request( 'post', _url, json = json, data = data, headers = headers, params = params )

        if response.status_code == 429: 

            print( "Message: %s" % ( response.json()['error']['message'] ) )

            if retries <= _maxNumRetries: 
                time.sleep(1) 
                retries += 1
                continue
            else: 
                print( 'Error: failed after retrying!' )
                break

        elif response.status_code == 200 or response.status_code == 201:

            if 'content-length' in response.headers and int(response.headers['content-length']) == 0: 
                result = None 
            elif 'content-type' in response.headers and isinstance(response.headers['content-type'], str): 
                if 'application/json' in response.headers['content-type'].lower(): 
                    result = response.json() if response.content else None 
                elif 'image' in response.headers['content-type'].lower(): 
                    result = response.content
        else:
            print( "Error code: %d" % ( response.status_code ) )
            print( "Message: %s" % ( response.json()['error']['message'] ) )

        break
        
    return result

# %%
from IPython.display import Image as ipImage, display

urlImage = 'https://i-technet.sec.s-msft.com/pt-br/mt629510.banne2(pt-br,MSDN.10).png'

img = ipImage(url=urlImage, width=400, height=400)
display(img)
# Out:
# <img src="https://i-technet.sec.s-msft.com/pt-br/mt629510.banne2(pt-br,MSDN.10).png" width="400" height="400"/>

# %%
headers = dict()
headers['Ocp-Apim-Subscription-Key'] = _key
headers['Content-Type'] = 'application/json' 

json = { 'url': urlImage } 
data = None

params = urllib.parse.urlencode({
    'visualFeatures': 'Categories,Tags,Description,Faces,ImageType,Color,Adult',
})

result = processRequest( json, data, headers, params )

# %%
import json

print(json.dumps(result, indent=2, sort_keys=True))
# Out:
# {
#   "language": "pt",
#   "orientation": "Up",
#   "regions": [
#     {
#       "boundingBox": "43,92,787,374",
#       "lines": [
#         {
#           "boundingBox": "47,92,653,30",
#           "words": [
#             {
#               "boundingBox": "47,99,21,23",
#               "text": "O"
#             },
#             {
#               "boundingBox": "80,92,131,30",
#               "text": "PR\u00d3XIMO"
#             },
#             {
#               "boundingBox": "222,99,87,23",
#               "text": "PASSO"
#             },
#             {
#               "boundingBox": "320,99,70,22",
#               "text": "PARA"
#             },
#             {
#               "boundingBox": "399,99,19,22",
#               "text": "A"
#             },
#             {
#               "boundingBox": "427,99,55,23",
#               "text": "SUA"
#             },
#             {
#               "boundingBox": "492,99,135,23",
#               "text": "CARREIRA"
#             },
#             {
#               "boundingBox": "637,92,63,30",
#               "text": "EST\u00c1"
#             }
#           ]
#         },
#         {
#           "boundingBox": "55,176,636,82",
#           "words": [
#             {
#               "boundingBox": "55,177,157,79",
#               "text": "NA"
#             },
#             {
#               "boundingBox": "276,176,415,82",
#               "text": "NUVEM"
#             }
#           ]
#         },
#         {
#           "boundingBox": "47,310,640,27",
#           "words": [
#             {
#               "boundingBox": "47,311,69,26",
#               "text": "Agora"
#             },
#             {
#               "boundingBox": "126,310,54,21",
#               "text": "voc\u00ea"
#             },
#             {
#               "boundingBox": "190,310,59,27",
#               "text": "pode"
#             },
#             {
#               "boundingBox": "257,313,32,18",
#               "text": "ter"
#             },
#             {
#               "boundingBox": "298,317,76,14",
#               "text": "acesso"
#             },
#             {
#               "boundingBox": "383,311,90,26",
#               "text": "gratuito"
#             },
#             {
#               "boundingBox": "483,317,27,14",
#               "text": "ao"
#             },
#             {
#               "boundingBox": "518,310,106,21",
#               "text": "Microsoft"
#             },
#             {
#               "boundingBox": "632,311,55,20",
#               "text": "Azur"
#             }
#           ]
#         },
#         {
#           "boundingBox": "47,349,648,20",
#           "words": [
#             {
#               "boundingBox": "47,349,94,20",
#               "text": "plataforma"
#             },
#             {
#               "boundingBox": "148,349,21,15",
#               "text": "de"
#             },
#             {
#               "boundingBox": "176,354,58,10",
#               "text": "nuvem"
#             },
#             {
#               "boundingBox": "241,349,21,15",
#               "text": "da"
#             },
#             {
#               "boundingBox": "269,349,86,15",
#               "text": "Microsoft."
#             },
#             {
#               "boundingBox": "363,350,45,14",
#               "text": "Basta"
#             },
#             {
#               "boundingBox": "415,354,26,10",
#               "text": "ser"
#             },
#             {
#               "boundingBox": "446,349,87,15",
#               "text": "estudante"
#             },
#             {
#               "boundingBox": "539,354,10,10",
#               "text": "e"
#             },
#             {
#               "boundingBox": "555,351,43,13",
#               "text": "estar"
#             },
#             {
#               "boundingBox": "604,349,63,15",
#               "text": "inscrito"
#             },
#             {
#               "boundingBox": "674,354,21,10",
#               "text": "no"
#             }
#           ]
#         },
#         {
#           "boundingBox": "48,378,265,25",
#           "words": [
#             {
#               "boundingBox": "48,384,105,19",
#               "text": "programa"
#             },
#             {
#               "boundingBox": "163,378,150,25",
#               "text": "DreamSpark."
#             }
#           ]
#         },
#         {
#           "boundingBox": "44,414,786,22",
#           "words": [
#             {
#               "boundingBox": "44,415,15,16",
#               "text": "O"
#             },
#             {
#               "boundingBox": "67,414,88,17",
#               "text": "Microsoft"
#             },
#             {
#               "boundingBox": "161,415,54,16",
#               "text": "Azure"
#             },
#             {
#               "boundingBox": "222,414,10,17",
#               "text": "\u00e9"
#             },
#             {
#               "boundingBox": "240,414,101,22",
#               "text": "compat\u00edvel"
#             },
#             {
#               "boundingBox": "349,420,39,11",
#               "text": "com"
#             },
#             {
#               "boundingBox": "396,414,74,17",
#               "text": "diversas"
#             },
#             {
#               "boundingBox": "477,414,111,22",
#               "text": "tecnologias:"
#             },
#             {
#               "boundingBox": "596,415,46,19",
#               "text": "Java,"
#             },
#             {
#               "boundingBox": "651,415,69,21",
#               "text": "MySQL"
#             },
#             {
#               "boundingBox": "727,420,10,11",
#               "text": "e"
#             },
#             {
#               "boundingBox": "744,415,86,16",
#               "text": "Xamarin."
#             }
#           ]
#         },
#         {
#           "boundingBox": "43,444,603,22",
#           "words": [
#             {
#               "boundingBox": "43,445,40,21",
#               "text": "Veja"
#             },
#             {
#               "boundingBox": "90,450,12,11",
#               "text": "o"
#             },
#             {
#               "boundingBox": "110,444,73,17",
#               "text": "material"
#             },
#             {
#               "boundingBox": "191,444,50,17",
#               "text": "abixo"
#             },
#             {
#               "boundingBox": "248,450,10,11",
#               "text": "e"
#             },
#             {
#               "boundingBox": "266,444,46,17",
#               "text": "saiba"
#             },
#             {
#               "boundingBox": "320,450,52,11",
#               "text": "como"
#             },
#             {
#               "boundingBox": "380,445,40,16",
#               "text": "criar"
#             },
#             {
#               "boundingBox": "427,445,76,21",
#               "text": "projetos"
#             },
#             {
#               "boundingBox": "511,444,135,22",
#               "text": "interoper\u00e1veis."
#             }
#           ]
#         }
#       ]
#     }
#   ],
#   "textAngle": 0.0
# }
